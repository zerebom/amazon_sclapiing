# %%
import sys;sys.path.append('./src')
import sqlite3
import re

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import re 
from collections import Counter

# %%
low_category_db='../data/database/1112_low_prodcuts_text_category.db'
high_category_db='../data/database/1112_high_prodcuts_text_category.db'
Hconn2,Hc2=get_db_conn(high_category_db)
Lconn2,Lc2=get_db_conn(low_category_db)
Lc2.execute('''select * from sqlite_master''')
for row in Lc2:
    print(row)
# Out:
# ('table', 'product_text', 'product_text', 2, 'CREATE TABLE product_text(id integer primary key,username,baka_star,each_id,pd_url,pd_star,pd_title,text_len,pd_text, category1, category2, category3, category4, category5, category6, category7, category8, category9, category10)')

# %%
Hc2.execute('''select distinct id,category1,category2,category3,category4,category5,category6,category7 from product_text where category6!='' ''')
i=0
for row in Hc2:
    print(row)
    i+=1
    if i==100:
        break
# Out:
# (54, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '理美容家電消耗品・アクセサリ', 'デンタルケア家電アクセサリ', '電動歯ブラシ用アクセサリ', '替えブラシ')
# (95, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', '補正下着', 'コルセット・ウエストニッパー', '')
# (193, '俺たちは天使じゃない', '(字幕版)', 'アトランティスのこころ', '(字幕版)', 'ペーパー・ムーン', '(字幕版)', 'めまい')
# (265, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '液体・クリーム洗顔料', '')
# (274, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '泡洗顔料', '')
# (360, 'ハードカバー', '￥', '5,235', 'より', '￥', '5,235', 'より')
# (362, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Politics', '&')
# (526, '参考価格:', '￥', '3,024', 'OFF:', '￥', '524', '(17%)')
# (645, '単行本', '￥', '1', 'より', '￥', '1', 'より')
# (667, '洋書', "Children's", 'Books', 'Holidays', '&', 'Celebrations', '')
# (1145, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', 'ロート', '')
# (1151, 'GHOST', 'IN', 'THE', 'SHELL/攻殻機動隊', '(レンタル版)', 'オリエント急行殺人事件', '(字幕版)')
# (1153, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '生活家電消耗品・アクセサリ', '掃除機用アクセサリ', '掃除機用バッテリー', '')
# (1163, 'プライムで視聴できます', 'アイアン・スカイ(字幕版)', 'プライムで視聴できます', '奇蹟がくれた数式(字幕版)', 'プライムで視聴できます', 'マイケル･ムーアの世界侵略のススメ(字幕版)', 'プライムで視聴できます')
# (1187, 'この曲を試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (1221, 'プライムで視聴できます', '家族はつらいよ２', 'プライムで視聴できます', '家族はつらいよ', 'プライムで視聴できます', 'おかあさんの木', 'プライムで視聴できます')
# (1226, 'プライムで視聴できます', 'ローレライ', 'プライムで視聴できます', '突入せよ！「あさま山荘」事件', 'プライムで視聴できます', 'アンダルシア', '女神の報復')
# (1469, '家電＆カメラ', 'アクセサリ・サプライ', 'AVアクセサリ', 'ケーブル', 'AV・ビジュアルケーブル', 'HDMIケーブル', '')
# (1805, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '生活家電消耗品・アクセサリ', '掃除機用アクセサリ', '掃除機用紙パック', '')
# (1982, 'この曲を試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (2039, 'この曲を試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (2040, 'この曲を試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (2057, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', 'みじん切り器・チョッパー', '')
# (2100, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', '補正下着', 'コルセット・ウエストニッパー', '')
# (2143, 'プライムで視聴できます', 'さまぁ～ず×さまぁ～ず', 'プライムで視聴できます', 'みうらじゅん&山田五郎の親爺同志', 'プライムで視聴できます', '内村さまぁ～ず', 'プライムで視聴できます')
# (2164, '家電＆カメラ', 'アクセサリ・サプライ', 'AVアクセサリ', 'ケーブル', 'AV・ビジュアルケーブル', 'HDMIケーブル', '')
# (2206, '家電＆カメラ', 'アクセサリ・サプライ', 'AVアクセサリ', 'ケーブル', 'AV・ビジュアルケーブル', 'HDMIケーブル', '')
# (2225, 'ホーム＆キッチン', '家電', '理美容家電', 'シェーバー・バリカン', 'レディースシェーバー・脱毛器', 'シェーバー', '')
# (2297, 'ムック', '￥', '1', 'より', '￥', '1', 'より')
# (2301, 'Kindle版', '￥', '1,300', '今すぐお読みいただけます:', '無料アプリ', 'ムック', '￥')
# (2469, 'ドラッグストア', '栄養補助食品', 'サプリメント・ビタミン', 'ビタミン', 'ビタミンB', 'ビオチン', '')
# (2684, '単行本', '￥', '1', 'より', '￥', '1', 'より')
# (2687, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '生活家電消耗品・アクセサリ', '掃除機用アクセサリ', '掃除機用交換部品', '')
# (2688, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '生活家電消耗品・アクセサリ', '掃除機用アクセサリ', '掃除機用交換部品', '')
# (2710, '家電＆カメラ', 'アクセサリ・サプライ', 'AVアクセサリ', 'ケーブル', 'AV・ビジュアルケーブル', 'HDMIケーブル', '')
# (2848, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '理美容家電消耗品・アクセサリ', 'デンタルケア家電アクセサリ', '電動歯ブラシ用アクセサリ', '替えブラシ')
# (2868, '参考価格:', '￥', '1,703', 'OFF:', '￥', '27', '(2%)')
# (2989, '単行本', '￥', '4,163', 'より', '￥', '4,163', 'より')
# (2999, '単行本（ソフトカバー）', '￥', '647', 'より', '￥', '647', 'より')
# (3010, 'ペーパーバック', '￥', '1,194', 'より', '￥', '1,194', 'より')
# (3016, '単行本', '￥', '3,017', 'より', '￥', '3,017', 'より')
# (3048, 'ペーパーバック', '￥', '154', 'より', '￥', '154', 'より')
# (3187, '洋書', 'Literature', '&', 'Fiction', "Women's", 'Fiction', '')
# (3407, 'ストリーミング', 'Unlimited', 'MP3', '￥', '1,050Amazon', 'Musicアプリを無料ダウンロードCD', '￥')
# (3439, 'A', 'Moon', 'Shaped', 'Pool', 'レディオヘッド5つ星のうち', '4.043￥', '1,500')
# (3652, '単行本（ソフトカバー）', '￥', '1,233', 'より', '￥', '1,233', 'より')
# (3718, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '理美容家電消耗品・アクセサリ', 'デンタルケア家電アクセサリ', '電動歯ブラシ用アクセサリ', '替えブラシ')
# (3768, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '理美容家電消耗品・アクセサリ', 'シェーバー・バリカン用消耗品・アクセサリ', 'シェーバー替刃', '')
# (3811, '洋書', 'Crafts,', 'Hobbies', '&', 'Home', 'Home', 'Improvement')
# (3905, 'ドラッグストア', '栄養補助食品', 'サプリメント・ビタミン', '必須脂肪酸・オイル', 'オメガオイル', 'オメガ3-6-9', '')
# (3909, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', 'そば・うどん用具', '')
# (3942, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', 'キッチン家電消耗品・アクセサリ', 'コーヒーメーカー用消耗品・アクセサリ', 'カプセルホルダー', '')
# (3944, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', 'キッチン家電消耗品・アクセサリ', 'コーヒーメーカー用消耗品・アクセサリ', 'カプセルホルダー', '')
# (3957, 'ゆれる', '幼な子われらに生まれ', '殺人者の記憶法', '新しい記憶(字幕版)', 'リベンジgirl', '今夜、ロマンス劇場で', '南瓜とマヨネーズ')
# (3973, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔フォーム', '')
# (4238, 'プライムで視聴できます', 'ワイルド・スピードX2', '(吹替版)', 'プライムで視聴できます', 'ワイルド・スピード', '(吹替版)', 'プライムで視聴できます')
# (4239, 'プライムで視聴できます', 'ワイルド・スピードX2', '(吹替版)', 'プライムで視聴できます', 'ワイルド・スピード', '(吹替版)', 'プライムで視聴できます')
# (4240, 'プライムで視聴できます', 'トランスポーター３', 'アンリミテッド(吹替版)', 'プライムで視聴できます', 'トランスポーター', '(字幕版)', 'プライムで視聴できます')
# (4241, 'プライムで視聴できます', 'ワイルド・スピードX2', '(吹替版)', 'プライムで視聴できます', 'ワイルド・スピード', '(吹替版)', 'プライムで視聴できます')
# (4242, 'プライムで視聴できます', 'ワイルド・スピード', '(吹替版)', 'プライムで視聴できます', 'ワイルド・スピードX3', 'TOKYO', 'DRIFT')
# (4243, 'プライムで視聴できます', 'ワイルド・スピードX2', '(吹替版)', 'プライムで視聴できます', 'ワイルド・スピードX3', 'TOKYO', 'DRIFT')
# (4244, 'プライムで視聴できます', 'チキンレース', 'プライムで視聴できます', '三谷幸喜「short', 'cut」', 'プライムで視聴できます', '隠し剣')
# (4245, 'プライムで視聴できます', 'パンとスープとネコ日和', 'プライムで視聴できます', 'センセイの鞄', 'プライムで視聴できます', '居酒屋ふじ', 'プライムで視聴できます')
# (4246, 'プライムで視聴できます', '東京難民', 'プライムで視聴できます', '二重生活', 'プライムで視聴できます', 'そこのみにて光輝く', 'プライムで視聴できます')
# (4248, 'プライムで視聴できます', '体脂肪計タニタの社員食堂', 'プライムで視聴できます', 'パンとスープとネコ日和', 'プライムで視聴できます', 'センセイの鞄', 'プライムで視聴できます')
# (4249, 'プライムで視聴できます', '映画｢アフタースクール｣【TBSオンデマンド】', 'プライムで視聴できます', 'ジヌよさらば', '～かむろば村へ～', 'プライムで視聴できます', 'ぱいかじ南海作戦')
# (4250, 'プライムで視聴できます', 'バクマン。', 'プライムで視聴できます', '脳内ポイズンベリー', 'プライムで視聴できます', 'セトウツミ', 'プライムで視聴できます')
# (4432, '洋書', 'Literature', '&', 'Fiction', 'History', '&', 'Criticism')
# (4661, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔せっけん', '')
# (4724, '洋書', 'Crafts,', 'Hobbies', '&', 'Home', 'Home', 'Improvement')
# (4749, 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas')
# (4819, 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas')
# (4903, 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas')
# (4921, 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas')
# (5044, 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas', 'no_datas')
# (5094, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔せっけん', '')
# (5157, '洋書', 'Crafts,', 'Hobbies', '&', 'Home', 'Home', 'Improvement')
# (5725, 'プライムで視聴できます', 'マイアミ・バイス', '(字幕版)', 'プライムで視聴できます', 'ウルフ・オブ・ウォールストリート(吹替版)', 'プライムで視聴できます', 'シャッター')
# (5993, 'プライムで視聴できます', 'ロボコップ２', '(吹替版)', 'プライムで視聴できます', '宇宙戦争', '(字幕版)', 'プライムで視聴できます')
# (6058, '洋書', 'Literature', '&', 'Fiction', 'Short', 'Stories', '')
# (6120, '単行本', '￥', '15,000', 'より', '￥', '15,000', 'より')
# (6298, 'DIY・工具・ガーデン', '電動工具・エア工具', '電動工具パーツ・アクセサリ', 'ドリルアクセサリ', 'アタッチメント', 'エクステンションバー', '')
# (6762, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (6790, '洋書', "Children's", 'Books', 'Arts,', 'Music', '&', 'Photography')
# (6855, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (6857, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (7018, '単行本', '￥', '1,548', 'より', '￥', '1,548', 'より')
# (7448, 'ボス・ベイビー', '(吹替版)', 'モンスターズ・ユニバーシティ(吹替版)', 'ミニオンズ', '３本', 'ミニ・ムービー・コレクション', '(吹替版)')
# (7453, 'プライムで視聴できます', 'クリーピー', '偽りの隣人', 'プライムで視聴できます', 'SCOOP!', 'プライムで視聴できます', '感染列島')
# (7473, 'ドゥーム', '(字幕版)', 'トータル・リコール', '劇場版', '(字幕版)', 'マトリックス', 'リローデッド(吹替版)')
# (7474, 'バイオハザード２', 'アポカリプス', '(吹替版)', 'バイオハザードⅣ', 'アフターライフ', '(字幕版)', 'アンダーワールド：ブラッド・ウォーズ')
# (7481, 'バイオハザードⅣ', 'アフターライフ', '(字幕版)', 'バイオハザード', '(字幕版)', 'バイオハザード２', 'アポカリプス')
# (7657, '洋書', 'Arts', '&', 'Photography', 'History', '&', 'Criticism')
# (7662, '単行本', '￥', '1,000', 'より', '￥', '1,000', 'より')
# (7975, '洋書', 'Professional', '&', 'Technical', 'Professional', 'Science', '')
# (8001, '洋書', 'Professional', '&', 'Technical', 'Professional', 'Science', '')
# (8009, '洋書', 'Professional', '&', 'Technical', 'Professional', 'Science', '')
# (8075, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Philosophy', '')
# (8086, '洋書', 'Literature', '&', 'Fiction', 'History', '&', 'Criticism')
# (8090, '洋書', 'Literature', '&', 'Fiction', 'Essays', '&', 'Correspondence')

# %%
Lc2.execute('''
select distinct id,category1,category2,category3,category4,category5,category6,category7
from product_text
where category1!='プ'  ''')


i=0
for row in Lc2:
    print(row)
    i+=1
    if i==100:
        break
# Out:
# (137, '単行本', '￥', '2,800', 'より', '￥', '2,800', 'より')
# (283, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔せっけん', '')
# (303, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', '焼き網', '')
# (324, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', 'アイスクリームディッシャー', '')
# (357, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔せっけん', '')
# (496, 'メアリと魔女の花', 'オリエント急行殺人事件', '(字幕版)', 'ベイビー・ドライバー', '(字幕版)', 'デッドプール２', '(吹替版)')
# (621, '産業・研究開発用品', '研究開発用品', '研究器具・実験用品', '洗浄機・洗浄用品', '超音波洗浄', '超音波洗浄機', '')
# (815, '洋書', 'Professional', '&', 'Technical', 'Business', 'Management', '')
# (818, '洋書', 'Professional', '&', 'Technical', 'Business', 'Management', '')
# (1050, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '空調・季節家電付属品・アクセサリ', 'エアコン用交換部品・アクセサリ', 'エアコン用接続部品', '')
# (1308, 'プライムで視聴できます', 'ケープタウン（字幕版）', 'プライムで視聴できます', 'ザ・シューター／極大射程', '(字幕版)', 'プライムで視聴できます', 'スパイ・レジェンド(字幕版)')
# (1415, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Politics', '&')
# (1423, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Politics', '&')
# (1424, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Politics', '&')
# (1431, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Sociology', '')
# (1435, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Politics', '&')
# (1441, '洋書', 'Education', '&', 'Reference', 'Writing,', 'Research', '&')
# (1838, 'ストリーミング', 'Unlimited', 'MP3', '￥', '1,500Amazon', 'Musicアプリを無料ダウンロードCD', '￥')
# (2215, '洋書', 'Professional', '&', 'Technical', 'Business', 'Management', '')
# (2255, '新書', '￥', '1', 'より', '￥', '1', 'より')
# (2287, '洋書', 'Biographies', '&', 'Memoirs', 'Specific', 'Groups', '')
# (2594, '大型本', '￥', '6,800', 'より', '￥', '6,800', 'より')
# (2664, '洋書', "Children's", 'Books', 'Literature', '&', 'Fiction', '')
# (2666, '洋書', 'Teen', '&', 'Young', 'Adult', 'Science', 'Fiction')
# (2668, '洋書', 'Crafts,', 'Hobbies', '&', 'Home', 'Pets', '&')
# (2669, '洋書', 'Cookbooks,', 'Food', '&', 'Wine', 'Culinary', 'Arts')
# (2670, '洋書', 'Teen', '&', 'Young', 'Adult', 'Science', 'Fiction')
# (3081, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', 'ミル', '')
# (3271, '単行本', '￥', '3,979', 'より', '￥', '3,979', 'より')
# (3540, '洋書', 'Professional', '&', 'Technical', 'Professional', 'Science', '')
# (3550, 'ムック', '￥', '5,980', 'より', '￥', '5,980', 'より')
# (3810, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '生活家電消耗品・アクセサリ', '掃除機用アクセサリ', '掃除機用交換部品', '')
# (3821, '家電＆カメラ', 'アクセサリ・サプライ', 'AVアクセサリ', 'ケーブル', 'AV・ビジュアルケーブル', 'HDMIケーブル', '')
# (3876, 'この曲を試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (3962, '洋書', "Children's", 'Books', 'Education', '&', 'Reference', '')
# (4099, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', '補正下着', '補正ショーツ・ガードル', '')
# (4115, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', '補正下着', 'ボディスーツ', '')
# (4161, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', 'ショーツ', 'サニタリーショーツ', '')
# (4174, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '理美容家電消耗品・アクセサリ', 'デンタルケア家電アクセサリ', '電動歯ブラシ用アクセサリ', '替えブラシ')
# (4186, 'ホーム＆キッチン', 'キッチン用品', '調理・製菓道具', '調理器具', 'その他の調理器具', 'シーラー', '')
# (4254, 'ドラッグストア', '栄養補助食品', 'サプリメント・ビタミン', '植物由来サプリメント', 'フルーツ由来サプリメント', 'アサイー', '')
# (4453, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '空調・季節家電付属品・アクセサリ', '加湿器用付属品・アクセサリ', '加湿器用フィルタ', '')
# (4454, '参考価格:', '￥', '5,076', 'OFF:', '￥', '3,576', '(70%)')
# (4473, '顔', '激動の昭和史', '沖縄決戦', 'ウィンストン・チャーチル／ヒトラーから世界を救った男', '(字幕版)', 'ウィンストン・チャーチル／ヒトラーから世界を救った男(吹替版)', '11.25自決の日')
# (4481, 'ALONE', 'アローン（字幕版）', 'リーグ・オブ・レジェンド／時空を超えた戦い', '(字幕版)', 'クリムゾン・タイド', '(吹替版)', '逃亡者')
# (4903, '洋書', 'Politics', '&', 'Social', 'Sciences', 'Politics', '&')
# (4924, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '泡洗顔料', '')
# (4986, '洋書', 'Crafts,', 'Hobbies', '&', 'Home', 'Crafts', '&')
# (4987, '洋書', 'Crafts,', 'Hobbies', '&', 'Home', 'Crafts', '&')
# (4989, 'プライムで視聴できます', 'コバート･アフェア', 'Season', '1', '(字幕版)', 'プライムで視聴できます', 'The')
# (4992, 'プライムで視聴できます', '一人之下', 'the', 'outcast', 'プライムで視聴できます', 'からくりサーカス', 'プライムで視聴できます')
# (4995, 'プライムで視聴できます', 'ホテルキング', 'プライムで視聴できます', 'キルミー・ヒールミー(字幕版)', 'プライムで視聴できます', 'コーヒープリンス1号店', '(字幕版)')
# (4996, 'プライムで視聴できます', 'ホテルキング', 'プライムで視聴できます', 'キルミー・ヒールミー(字幕版)', 'プライムで視聴できます', 'コーヒープリンス1号店', '(字幕版)')
# (5001, 'プライムで視聴できます', '大奥', '～永遠～', '［右衛門佐・綱吉篇］', 'プライムで視聴できます', 'さくらん', 'プライムで視聴できます')
# (5417, 'プライムで視聴できます', 'マイアミ・バイス', '(字幕版)', 'プライムで視聴できます', 'ウルフ・オブ・ウォールストリート(吹替版)', 'プライムで視聴できます', 'シャッター')
# (5434, 'プライムで視聴できます', '神さまの言うとおり', 'プライムで視聴できます', '怒り', 'プライムで視聴できます', '悪の教典', 'プライムで視聴できます')
# (5441, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔フォーム', '')
# (5568, '洋書', 'Computers', '&', 'Technology', 'Web', 'Development', '&')
# (5617, 'ストリーミング', 'Unlimited', 'MP3', '￥', '640Amazon', 'Musicアプリを無料ダウンロードCD', '￥')
# (5726, 'ドラッグストア', '栄養補助食品', 'サプリメント・ビタミン', 'ビタミン', 'ビタミンB', '葉酸', '')
# (5738, '洋書', 'Education', '&', 'Reference', 'Atlases', '&', 'Maps')
# (5755, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (5959, '参考価格:', '￥', '5,076', 'OFF:', '￥', '1,116', '(22%)')
# (6286, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '理美容家電消耗品・アクセサリ', 'デンタルケア家電アクセサリ', '電動歯ブラシ用アクセサリ', '替えブラシ')
# (6317, 'プライムで視聴できます', 'ゼロの真実～監察医・松本真央～', 'プライムで視聴できます', 'パズル', 'プライムで視聴できます', '特命刑事カクホの女', 'プライムで視聴できます')
# (6340, '洋書', 'Arts', '&', 'Photography', 'History', '&', 'Criticism')
# (6345, '単行本', '￥', '1,080', 'より', '￥', '1,080', 'より')
# (6699, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '空調・季節家電付属品・アクセサリ', '空気清浄機用付属品・アクセサリ', '空気清浄機用フィルタ', '')
# (6707, 'ストリーミング', 'Unlimited', 'MP3', '￥', '1,800Amazon', 'Musicアプリを無料ダウンロードCD', '￥')
# (6710, 'このアルバムを試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (6719, 'このアルバムを試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (6720, 'このアルバムを試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (6726, 'このアルバムを試聴する', 'タイトル', '：', 'アーティスト', '0:00', '/', '0:00')
# (6834, 'ホーム＆キッチン', '家電', '消耗品・アクセサリ', '空調・季節家電付属品・アクセサリ', 'エアコン用交換部品・アクセサリ', 'エアコン用リモコン', '')
# (6913, '単行本（ソフトカバー）', '￥', '797', 'より', '￥', '797', 'より')
# (6915, 'サイボーグ００９', 'プライムで視聴できます', '破裏拳ポリマー', 'プライムで視聴できます', 'ウルトラQ', 'プライムで視聴できます', '海底大戦争')
# (7069, 'プライムで視聴できます', 'ホリデイ', '(字幕版)', 'プライムで視聴できます', '親愛なるきみへ(字幕版)', 'プライムで視聴できます', 'ONCE')
# (7070, 'ダンガル', 'きっと、つよくなる', '〈オリジナル版〉(字幕版)', 'プライムで視聴できます', 'キャッチ・ミー・イフ・ユー・キャン', '(字幕版)', 'プライムで視聴できます')
# (7395, 'プライムで視聴できます', '特攻フルスインガー', 'プライムで視聴できます', '千原◯ニアの◯◯-1GP', 'プライムで視聴できます', '坂上忍流ディープな夜遊び', 'プライムで視聴できます')
# (7396, 'プライムで視聴できます', 'イーグル・アイ', '(字幕版)', 'プライムで視聴できます', 'スパイ・レジェンド(字幕版)', 'プライムで視聴できます', 'ザ・ゲスト(字幕版)')
# (7397, 'プライムで視聴できます', 'ヤッさん', 'プライムで視聴できます', '居酒屋ふじ', 'プライムで視聴できます', '女くどき飯', 'プライムで視聴できます')
# (7668, 'ビューティー', 'スキンケア・ボディケア', 'スキンケア・基礎化粧品', '洗顔', '洗顔料', '洗顔フォーム', '')
# (7812, 'ドラッグストア', '栄養補助食品', 'サプリメント・ビタミン', '植物由来サプリメント', 'フルーツ由来サプリメント', 'ザクロ', '')
# (7824, 'ドラッグストア', '栄養補助食品', 'サプリメント・ビタミン', '植物由来サプリメント', 'フルーツ由来サプリメント', 'ザクロ', '')
# (7871, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', 'ショーツ', 'サニタリーショーツ', '')
# (7895, '服＆ファッション小物', 'レディース', 'インナーウェア・ルームウェア', 'インナーウェア', 'ランジェリーアクセサリ', 'ブラエクステンダー', '')
# (7982, '洋書', "Children's", 'Books', 'Activities,', 'Crafts', '&', 'Games')
# (7990, '洋書', "Children's", 'Books', 'Education', '&', 'Reference', '')
# (7996, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (8002, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (8003, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')
# (8005, 'ホーム＆キッチン', '家電', '理美容家電', 'シェーバー・バリカン', 'レディースシェーバー・脱毛器', 'シェーバー', '')
# (8006, '洋書', "Children's", 'Books', 'Growing', 'Up', '&', 'Facts')

# %%
Lc2.execute('''select distinct category1,category2,category3,category4 from product_text ''')
Hc2.execute('''select distinct category1,category2,category3,category4 from product_text ''')

low_category=[x[0] for x in Lc2]
high_category=[x[0] for x in Hc2]

low_counter=Counter(low_category)
high_counter=Counter(high_category)

# %%
import matplotlib as mpl
mpl.matplotlib_fname()
mpl.font_manager._rebuild()

# %%
Lvalues,Lcounts=list(zip(*low_counter.most_common(30)))

#20字以上のラベルは除去している
Lvalues=[x[:20] for x in Lvalues]

plt.style.use('ggplot')
plt.rcParams.update({'font.size':18})
#日本語対応FONT
plt.rcParams['font.family'] = 'IPAPGothic'

size=(8,8)
col=cm.Spectral(np.arange(len(Lcounts))/float(len(Lcounts))) #color指定はcolormapから好みのものを。

plt.figure(figsize=size,dpi=200)
plt.pie(Lcounts,colors=col,counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.9)
plt.legend(Lvalues,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('低評価category1.png',bbox_inches='tight',pad_inches=0.05)

# %%
Hvalues,Hcounts=list(zip(*high_counter.most_common(30)))

#20字以上のラベルは除去している
Hvalues=[x[:20] for x in Hvalues]

plt.style.use('ggplot')
plt.rcParams.update({'font.size':18})
#日本語対応FONT
plt.rcParams['font.family'] = 'IPAPGothic'

size=(8,8)
col=cm.Spectral(np.arange(len(Hcounts))/float(len(Hcounts))) #color指定はcolormapから好みのものを。

plt.figure(figsize=size,dpi=200)
plt.pie(Hcounts,colors=col,counterclock=False,startangle=90,autopct=lambda p:'{:.1f}%'.format(p) if p>=5 else '')
plt.subplots_adjust(left=0,right=0.9)
plt.legend(Hvalues,fancybox=True,loc='center left',bbox_to_anchor=(0.9,0.5))
plt.axis('equal') 
plt.savefig('高評価category1.png',bbox_inches='tight',pad_inches=0.05)

# %%
create_pie_fig(Hcounts,Hvalues,'高評価category1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-21aaef7312ad> in <module>
# ----> 1 create_pie_fig(Hcounts,Hvalues,'高評価category1.png')
#
# NameError: name 'create_pie_fig' is not defined

# %%
from control_db import *
